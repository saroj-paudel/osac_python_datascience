# %%
import pandas as pd

# %%
# arr = my_series.to_numpy()

# %%
df = pd.read_csv("student_records.csv")

# %%
df
# Out:
#                Name Roll_No   Age  Total_Marks     Address Grade  \
# 0     Prakash Karki    R001  16.0        248.0    Lalitpur     C
# 1   Anisha Shrestha    R002  16.0        467.0     Surkhet     C
# 2    Pooja Bhandari    R003  17.0        367.0  Biratnagar     A
# 3      Pooja Sharma    R004  19.0        228.0    Lalitpur     A
# 4    Aarav Shrestha    R005  20.0        386.0      Butwal     B
# 5       Sita Gurung    R006  19.0        361.0      Butwal     C
# 6      Pooja Sharma    R007  17.0        245.0    Lalitpur     B
# 7    Bibek Shrestha    R008  16.0        449.0   Bhaktapur     D
# 8   Ramesh Bhandari    R009  20.0        258.0     Birgunj     B
# 9     Nirajan Karki    R010  16.0        459.0   Kathmandu     C
# 10       Sita Karki    R011  16.0        471.0  Bhairahawa     B
# 11      Pooja Thapa    R012   NaN        495.0       Palpa     B
# 12   Nirajan Gurung    R013  20.0          NaN   Bhaktapur     A
# ...

# %%
df.isna()
# Out:
#      Name  Roll_No    Age  Total_Marks  Address  Grade  Email
# 0   False    False  False        False    False  False  False
# 1   False    False  False        False    False  False  False
# 2   False    False  False        False    False  False  False
# 3   False    False  False        False    False  False  False
# 4   False    False  False        False    False  False  False
# 5   False    False  False        False    False  False  False
# 6   False    False  False        False    False  False  False
# 7   False    False  False        False    False  False  False
# 8   False    False  False        False    False  False  False
# 9   False    False  False        False    False  False  False
# 10  False    False  False        False    False  False   True
# 11  False    False   True        False    False  False  False
# 12  False    False  False         True    False  False  False
# 13  False    False  False        False    False  False   True
# ...

# %%
df.isna().sum()
# Out:
# Name           0
# Roll_No        0
# Age            7
# Total_Marks    2
# Address        1
# Grade          3
# Email          4
# dtype: int64

# %%
df_clean_all = df.dropna()

# %%
df_clean_all
# Out:
#                Name Roll_No   Age  Total_Marks     Address Grade  \
# 0     Prakash Karki    R001  16.0        248.0    Lalitpur     C
# 1   Anisha Shrestha    R002  16.0        467.0     Surkhet     C
# 2    Pooja Bhandari    R003  17.0        367.0  Biratnagar     A
# 3      Pooja Sharma    R004  19.0        228.0    Lalitpur     A
# 4    Aarav Shrestha    R005  20.0        386.0      Butwal     B
# 5       Sita Gurung    R006  19.0        361.0      Butwal     C
# 6      Pooja Sharma    R007  17.0        245.0    Lalitpur     B
# 7    Bibek Shrestha    R008  16.0        449.0   Bhaktapur     D
# 8   Ramesh Bhandari    R009  20.0        258.0     Birgunj     B
# 9     Nirajan Karki    R010  16.0        459.0   Kathmandu     C
# 14      Prakash Rai    R015  17.0        227.0   Nepalgunj     B
# 17     Pooja Gurung    R018  18.0        490.0     Pokhara     A
# 20         Sudip KC    R021  18.0        492.0       Jhapa     C
# ...

# %%
df_clean_selective= df.dropna(subset= ["Age", "Total_Marks"])

# %%
df_clean_selective
# Out:
#                Name Roll_No   Age  Total_Marks     Address Grade  \
# 0     Prakash Karki    R001  16.0        248.0    Lalitpur     C
# 1   Anisha Shrestha    R002  16.0        467.0     Surkhet     C
# 2    Pooja Bhandari    R003  17.0        367.0  Biratnagar     A
# 3      Pooja Sharma    R004  19.0        228.0    Lalitpur     A
# 4    Aarav Shrestha    R005  20.0        386.0      Butwal     B
# 5       Sita Gurung    R006  19.0        361.0      Butwal     C
# 6      Pooja Sharma    R007  17.0        245.0    Lalitpur     B
# 7    Bibek Shrestha    R008  16.0        449.0   Bhaktapur     D
# 8   Ramesh Bhandari    R009  20.0        258.0     Birgunj     B
# 9     Nirajan Karki    R010  16.0        459.0   Kathmandu     C
# 10       Sita Karki    R011  16.0        471.0  Bhairahawa     B
# 13      Pooja Karki    R014  17.0        386.0     Hetauda     C
# 14      Prakash Rai    R015  17.0        227.0   Nepalgunj     B
# ...

# %%
df["Age"].fillna(df["Age"].median(), inplace=True)
# Out:
# C:\Users\ram\AppData\Local\Temp\ipykernel_13108\2097741607.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Age"].fillna(df["Age"].median(), inplace=True)

# %%
df
# Out:
#                Name Roll_No   Age  Total_Marks     Address Grade  \
# 0     Prakash Karki    R001  16.0        248.0    Lalitpur     C
# 1   Anisha Shrestha    R002  16.0        467.0     Surkhet     C
# 2    Pooja Bhandari    R003  17.0        367.0  Biratnagar     A
# 3      Pooja Sharma    R004  19.0        228.0    Lalitpur     A
# 4    Aarav Shrestha    R005  20.0        386.0      Butwal     B
# 5       Sita Gurung    R006  19.0        361.0      Butwal     C
# 6      Pooja Sharma    R007  17.0        245.0    Lalitpur     B
# 7    Bibek Shrestha    R008  16.0        449.0   Bhaktapur     D
# 8   Ramesh Bhandari    R009  20.0        258.0     Birgunj     B
# 9     Nirajan Karki    R010  16.0        459.0   Kathmandu     C
# 10       Sita Karki    R011  16.0        471.0  Bhairahawa     B
# 11      Pooja Thapa    R012  18.0        495.0       Palpa     B
# 12   Nirajan Gurung    R013  20.0          NaN   Bhaktapur     A
# ...

# %%
df["Total_Marks"].fillna(df["Total_Marks"].median(), inplace=True)
# Out:
# C:\Users\ram\AppData\Local\Temp\ipykernel_13108\2973060478.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Total_Marks"].fillna(df["Total_Marks"].median(), inplace=True)

# %%
df
# Out:
#                Name Roll_No   Age  Total_Marks     Address Grade  \
# 0     Prakash Karki    R001  16.0        248.0    Lalitpur     C
# 1   Anisha Shrestha    R002  16.0        467.0     Surkhet     C
# 2    Pooja Bhandari    R003  17.0        367.0  Biratnagar     A
# 3      Pooja Sharma    R004  19.0        228.0    Lalitpur     A
# 4    Aarav Shrestha    R005  20.0        386.0      Butwal     B
# 5       Sita Gurung    R006  19.0        361.0      Butwal     C
# 6      Pooja Sharma    R007  17.0        245.0    Lalitpur     B
# 7    Bibek Shrestha    R008  16.0        449.0   Bhaktapur     D
# 8   Ramesh Bhandari    R009  20.0        258.0     Birgunj     B
# 9     Nirajan Karki    R010  16.0        459.0   Kathmandu     C
# 10       Sita Karki    R011  16.0        471.0  Bhairahawa     B
# 11      Pooja Thapa    R012  18.0        495.0       Palpa     B
# 12   Nirajan Gurung    R013  20.0        386.0   Bhaktapur     A
# ...

# %%
df["Address"].fillna("Unknown", inplace=True)
# Out:
# C:\Users\ram\AppData\Local\Temp\ipykernel_13108\2485826477.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Address"].fillna("Unknown", inplace=True)

# %%
df
# Out:
#                Name Roll_No   Age  Total_Marks     Address Grade  \
# 0     Prakash Karki    R001  16.0        248.0    Lalitpur     C
# 1   Anisha Shrestha    R002  16.0        467.0     Surkhet     C
# 2    Pooja Bhandari    R003  17.0        367.0  Biratnagar     A
# 3      Pooja Sharma    R004  19.0        228.0    Lalitpur     A
# 4    Aarav Shrestha    R005  20.0        386.0      Butwal     B
# 5       Sita Gurung    R006  19.0        361.0      Butwal     C
# 6      Pooja Sharma    R007  17.0        245.0    Lalitpur     B
# 7    Bibek Shrestha    R008  16.0        449.0   Bhaktapur     D
# 8   Ramesh Bhandari    R009  20.0        258.0     Birgunj     B
# 9     Nirajan Karki    R010  16.0        459.0   Kathmandu     C
# 10       Sita Karki    R011  16.0        471.0  Bhairahawa     B
# 11      Pooja Thapa    R012  18.0        495.0       Palpa     B
# 12   Nirajan Gurung    R013  20.0        386.0   Bhaktapur     A
# ...

# %%
df["Grade"].fillna("Unknown", inplace=True)
# Out:
# C:\Users\ram\AppData\Local\Temp\ipykernel_13108\4188973986.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Grade"].fillna("Unknown", inplace=True)

# %%
df
# Out:
#                Name Roll_No   Age  Total_Marks     Address    Grade  \
# 0     Prakash Karki    R001  16.0        248.0    Lalitpur        C
# 1   Anisha Shrestha    R002  16.0        467.0     Surkhet        C
# 2    Pooja Bhandari    R003  17.0        367.0  Biratnagar        A
# 3      Pooja Sharma    R004  19.0        228.0    Lalitpur        A
# 4    Aarav Shrestha    R005  20.0        386.0      Butwal        B
# 5       Sita Gurung    R006  19.0        361.0      Butwal        C
# 6      Pooja Sharma    R007  17.0        245.0    Lalitpur        B
# 7    Bibek Shrestha    R008  16.0        449.0   Bhaktapur        D
# 8   Ramesh Bhandari    R009  20.0        258.0     Birgunj        B
# 9     Nirajan Karki    R010  16.0        459.0   Kathmandu        C
# 10       Sita Karki    R011  16.0        471.0  Bhairahawa        B
# 11      Pooja Thapa    R012  18.0        495.0       Palpa        B
# 12   Nirajan Gurung    R013  20.0        386.0   Bhaktapur        A
# ...

# %%
df["Email"].fillna("unknown@gmail.com", inplace=True)
# Out:
# C:\Users\ram\AppData\Local\Temp\ipykernel_13108\1374399229.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Email"].fillna("unknown@gmail.com", inplace=True)

# %%
df
# Out:
#                Name Roll_No   Age  Total_Marks     Address    Grade  \
# 0     Prakash Karki    R001  16.0        248.0    Lalitpur        C
# 1   Anisha Shrestha    R002  16.0        467.0     Surkhet        C
# 2    Pooja Bhandari    R003  17.0        367.0  Biratnagar        A
# 3      Pooja Sharma    R004  19.0        228.0    Lalitpur        A
# 4    Aarav Shrestha    R005  20.0        386.0      Butwal        B
# 5       Sita Gurung    R006  19.0        361.0      Butwal        C
# 6      Pooja Sharma    R007  17.0        245.0    Lalitpur        B
# 7    Bibek Shrestha    R008  16.0        449.0   Bhaktapur        D
# 8   Ramesh Bhandari    R009  20.0        258.0     Birgunj        B
# 9     Nirajan Karki    R010  16.0        459.0   Kathmandu        C
# 10       Sita Karki    R011  16.0        471.0  Bhairahawa        B
# 11      Pooja Thapa    R012  18.0        495.0       Palpa        B
# 12   Nirajan Gurung    R013  20.0        386.0   Bhaktapur        A
# ...

# %%
df.sort_values(by=["Total_Marks","Age"], ascending=False ,inplace=True)

# %%
df
# Out:
#                Name Roll_No   Age  Total_Marks     Address    Grade  \
# 11      Pooja Thapa    R012  18.0        495.0       Palpa        B
# 22       Aarav Lama    R023  20.0        492.0        Ilām        A
# 20         Sudip KC    R021  18.0        492.0       Jhapa        C
# 17     Pooja Gurung    R018  18.0        490.0     Pokhara        A
# 27    Ritika Basnet    R028  18.0        483.0     Surkhet        A
# 28     Anisha Thapa    R029  18.0        471.0      Dharan        B
# 10       Sita Karki    R011  16.0        471.0  Bhairahawa        B
# 1   Anisha Shrestha    R002  16.0        467.0     Surkhet        C
# 9     Nirajan Karki    R010  16.0        459.0   Kathmandu        C
# 7    Bibek Shrestha    R008  16.0        449.0   Bhaktapur        D
# 15    Sita Shrestha    R016  18.0        423.0     Unknown        C
# 18       Ramesh Rai    R019  19.0        418.0  Bhairahawa  Unknown
# 29        Bibek Rai    R030  16.0        395.0     Surkhet        D
# ...

# %%
df[["First_Name","Last_Name"]] = df["Name"].str.split(" ", expand=True)

# %%
df
# Out:
#                Name Roll_No   Age  Total_Marks     Address    Grade  \
# 11      Pooja Thapa    R012  18.0        495.0       Palpa        B
# 22       Aarav Lama    R023  20.0        492.0        Ilām        A
# 20         Sudip KC    R021  18.0        492.0       Jhapa        C
# 17     Pooja Gurung    R018  18.0        490.0     Pokhara        A
# 27    Ritika Basnet    R028  18.0        483.0     Surkhet        A
# 28     Anisha Thapa    R029  18.0        471.0      Dharan        B
# 10       Sita Karki    R011  16.0        471.0  Bhairahawa        B
# 1   Anisha Shrestha    R002  16.0        467.0     Surkhet        C
# 9     Nirajan Karki    R010  16.0        459.0   Kathmandu        C
# 7    Bibek Shrestha    R008  16.0        449.0   Bhaktapur        D
# 15    Sita Shrestha    R016  18.0        423.0     Unknown        C
# 18       Ramesh Rai    R019  19.0        418.0  Bhairahawa  Unknown
# 29        Bibek Rai    R030  16.0        395.0     Surkhet        D
# ...

# %%
df.to_csv("studentRecords_cleaned.csv", index=False)
