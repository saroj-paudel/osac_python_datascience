# %%
import pandas as pd

# %%
df = pd.read_csv("diabetes.csv")

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %% [markdown]
# ## Part 1

# %%
df.sort_values(by="Age")
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 255            1      113             64             35        0  33.6
# 60             2       84              0              0        0   0.0
# 102            0      125             96              0        0  22.5
# 182            1        0             74             20       23  27.7
# 623            0       94             70             27      115  43.5
# ..           ...      ...            ...            ...      ...   ...
# 123            5      132             80              0        0  26.8
# 684            5      136             82              0        0   0.0
# 666            4      145             82             18        0  32.5
# 453            2      119              0              0        0  19.6
# 459            9      134             74             33       60  25.9
#
#      DiabetesPedigreeFunction  Age  Outcome
# 255                     0.543   21        1
# ...

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df.sort_values("Age")
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 255            1      113             64             35        0  33.6
# 60             2       84              0              0        0   0.0
# 102            0      125             96              0        0  22.5
# 182            1        0             74             20       23  27.7
# 623            0       94             70             27      115  43.5
# ..           ...      ...            ...            ...      ...   ...
# 123            5      132             80              0        0  26.8
# 684            5      136             82              0        0   0.0
# 666            4      145             82             18        0  32.5
# 453            2      119              0              0        0  19.6
# 459            9      134             74             33       60  25.9
#
#      DiabetesPedigreeFunction  Age  Outcome
# 255                     0.543   21        1
# ...

# %%
df.sort_values(by="BMI",ascending=False)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 177            0      129            110             46      130  67.1
# 445            0      180             78             63       14  59.4
# 673            3      123            100             35      240  57.3
# 125            1       88             30             42       99  55.0
# 120            0      162             76             56      100  53.2
# ..           ...      ...            ...            ...      ...   ...
# 81             2       74              0              0        0   0.0
# 371            0      118             64             23       89   0.0
# 522            6      114              0              0        0   0.0
# 49             7      105              0              0        0   0.0
# 706           10      115              0              0        0   0.0
#
#      DiabetesPedigreeFunction  Age  Outcome
# 177                     0.319   26        1
# ...

# %% [markdown]
# ## Part 2

# %%
older = df["Age"] > 60

# %%
older_df=df.loc[older]

# %%
older_df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 115            4      146             92              0        0  31.2
# 123            5      132             80              0        0  26.8
# 129            0      105             84              0        0  27.9
# 148            5      147             78              0        0  33.7
# 221            2      158             90              0        0  31.6
# 223            7      142             60             33      190  28.8
# 263            3      142             80             15        0  32.4
# 294            0      161             50              0        0  21.9
# 361            5      158             70              0        0  29.8
# 362            5      103            108             37        0  39.2
# 363            4      146             78              0        0  38.5
# 453            2      119              0              0        0  19.6
# ...

# %%
len(older_df)
# Out:
# 27

# %%
outcome_1 = df.loc[df["Outcome"]== 1]

# %%
outcome_1
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 2              8      183             64              0        0  23.3
# 4              0      137             40             35      168  43.1
# 6              3       78             50             32       88  31.0
# 8              2      197             70             45      543  30.5
# ..           ...      ...            ...            ...      ...   ...
# 755            1      128             88             39      110  36.5
# 757            0      123             72              0        0  36.3
# 759            6      190             92              0        0  35.5
# 761            9      170             74             31        0  44.0
# 766            1      126             60              0        0  30.1
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
outcome_0 = df.loc[df["Outcome"] == 0]

# %%
outcome_0
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 1              1       85             66             29        0  26.6
# 3              1       89             66             23       94  28.1
# 5              5      116             74              0        0  25.6
# 7             10      115              0              0        0  35.3
# 10             4      110             92              0        0  37.6
# ..           ...      ...            ...            ...      ...   ...
# 762            9       89             62              0        0  22.5
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 1                       0.351   31        0
# ...

# %%
insulin_0 = df.loc[df["Insulin"] == 0]

# %%
insulin_0
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 5              5      116             74              0        0  25.6
# 7             10      115              0              0        0  35.3
# ..           ...      ...            ...            ...      ...   ...
# 761            9      170             74             31        0  44.0
# 762            9       89             62              0        0  22.5
# 764            2      122             70             27        0  36.8
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
high_glucose = df.loc[df["Glucose"] > 180]

# %%
high_glucose
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 2              8      183             64              0        0  23.3
# 8              2      197             70             45      543  30.5
# 13             1      189             60             23      846  30.1
# 22             7      196             90              0        0  39.8
# 56             7      187             68             39      304  37.7
# 154            8      188             78              0        0  47.9
# 185            7      194             68             28        0  35.9
# 186            8      181             68             36      495  30.1
# 206            8      196             76             29      280  37.5
# 209            7      184             84             33        0  35.5
# 228            4      197             70             39      744  36.7
# 236            7      181             84             21      192  35.9
# ...

# %% [markdown]
# ## Part 3

# %%
high_risk_young_patient = df.loc[(df["Age"] < 30) & (df["BMI"] > 35)]

# %%
high_risk_young_patient
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 7             10      115              0              0        0  35.3
# 20             3      126             88             41      235  39.3
# 38             2       90             68             42        0  38.2
# 45             0      180             66             39        0  42.0
# 59             0      105             64             41      142  41.5
# ..           ...      ...            ...            ...      ...   ...
# 746            1      147             94             41        0  49.3
# 751            1      121             78             39       74  39.0
# 753            0      181             88             44      510  43.3
# 758            1      106             76              0        0  37.5
# 764            2      122             70             27        0  36.8
#
#      DiabetesPedigreeFunction  Age  Outcome
# 7                       0.134   29        0
# ...

# %%
spefific_health_markers = df.loc[(df["BloodPressure"]> 90) | (df["Glucose"] > 160)]

# %%
spefific_health_markers
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 2              8      183             64              0        0  23.3
# 8              2      197             70             45      543  30.5
# 9              8      125             96              0        0   0.0
# 10             4      110             92              0        0  37.6
# 11            10      168             74              0        0  38.0
# ..           ...      ...            ...            ...      ...   ...
# 748            3      187             70             22      200  36.4
# 749            6      162             62              0        0  24.3
# 753            0      181             88             44      510  43.3
# 759            6      190             92              0        0  35.5
# 761            9      170             74             31        0  44.0
#
#      DiabetesPedigreeFunction  Age  Outcome
# 2                       0.672   32        1
# ...

# %%
healthy_and_young = high_risk_young_patient = df.loc[(df["Age"] < 25) & (df["Outcome"] == 0)]

# %%
healthy_and_young
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 3              1       89             66             23       94  28.1
# 27             1       97             66             15      140  23.2
# 32             3       88             58             11       54  24.8
# 47             2       71             70             27        0  28.0
# 49             7      105              0              0        0   0.0
# ..           ...      ...            ...            ...      ...   ...
# 736            0      126             86             27      120  27.4
# 738            2       99             60             17      160  36.6
# 742            1      109             58             18      116  28.5
# 760            2       88             58             26       16  28.4
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 3                       0.167   21        0
# ...

# %%
normal_bmi = df.loc[(df["BMI"] < 29.9) & (df["BMI"] > 25)]

# %%
normal_bmi
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 1              1       85             66             29        0  26.6
# 3              1       89             66             23       94  28.1
# 5              5      116             74              0        0  25.6
# 12            10      139             80              0        0  27.1
# 14             5      166             72             19      175  25.8
# ..           ...      ...            ...            ...      ...   ...
# 736            0      126             86             27      120  27.4
# 742            1      109             58             18      116  28.5
# 752            3      108             62             24        0  26.0
# 760            2       88             58             26       16  28.4
# 765            5      121             72             23      112  26.2
#
#      DiabetesPedigreeFunction  Age  Outcome
# 1                       0.351   31        0
# ...

# %%
null_value_investigate = df.loc[(df["BloodPressure"] > 0) & (df["BMI"] > 0) & (df["Glucose"] > 0)]

# %%
null_value_investigate
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %% [markdown]
# ## Part 4

# %%
top_diabetic = df.loc[df["Outcome"] == 1]

# %%
top_diabetic.sort_values(by="Glucose",ascending=False, inplace=True)
# Out:
# C:\Users\ram\AppData\Local\Temp\ipykernel_14028\388795565.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   top_diabetic.sort_values(by="Glucose",ascending=False, inplace=True)

# %%
top_diabetic.head(10)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 661            1      199             76             43        0  42.9
# 561            0      198             66             32      274  41.3
# 579            2      197             70             99        0  34.7
# 408            8      197             74              0        0  25.9
# 8              2      197             70             45      543  30.5
# 22             7      196             90              0        0  39.8
# 359            1      196             76             36      249  36.5
# 206            8      196             76             29      280  37.5
# 675            6      195             70              0        0  30.9
# 498            7      195             70             33      145  25.1
#
#      DiabetesPedigreeFunction  Age  Outcome
# 661                     1.394   22        1
# 561                     0.502   28        1
# 579                     0.575   62        1
# ...

# %%
youngest_patients_with_high_insulin = df.loc[df["Insulin"] > 200]

# %%
youngest_patients_with_high_insulin.sort_values(by=["Age"],inplace=True)
# Out:
# C:\Users\ram\AppData\Local\Temp\ipykernel_14028\117319355.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   youngest_patients_with_high_insulin.sort_values(by=["Age"],inplace=True)

# %%
youngest_patients_with_high_insulin.head()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 713            0      134             58             20      291  26.4
# 486            1      139             62             41      480  40.7
# 220            0      177             60             29      478  34.6
# 511            0      139             62             17      210  22.1
# 392            1      131             64             14      415  23.7
#
#      DiabetesPedigreeFunction  Age  Outcome
# 713                     0.352   21        0
# 486                     0.536   21        0
# 220                     1.072   21        1
# 511                     0.207   21        0
# 392                     0.389   21        0

# %%
pregnancy_and_pedigree = df.loc[df["Pregnancies"] > 5].sort_values(by="DiabetesPedigreeFunction",ascending=False)

# %%
pregnancy_and_pedigree
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 330            8      118             72             19        0  23.1
# 622            6      183             94              0        0  40.8
# 12            10      139             80              0        0  27.1
# 259           11      155             76             28      150  33.3
# 243            6      119             50             22      176  27.1
# ..           ...      ...            ...            ...      ...   ...
# 329            6      105             70             32       68  30.8
# 560            6      125             76              0        0  33.8
# 146            9       57             80             37        0  32.8
# 567            6       92             62             32      126  32.0
# 180            6       87             80              0        0  23.2
#
#      DiabetesPedigreeFunction  Age  Outcome
# 330                     1.476   46        0
# ...

# %% [markdown]
# ## Part 5

# %%
high_risk_profile = df.loc[ (df["Age"] > 45) & (df["BMI"] > 30) & (df["Glucose"] > 150)]

# %%
high_risk_profile.shape[0] # len(high_risk_profile)
# Out:
# 23

# %%
new_data = df["Pregnancies"].isin([1,3,5]) # df.isin({"Pregnancies":[1,3,5]})

# %%
df[new_data]
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 1              1       85             66             29        0  26.6
# 3              1       89             66             23       94  28.1
# 5              5      116             74              0        0  25.6
# 6              3       78             50             32       88  31.0
# 13             1      189             60             23      846  30.1
# ..           ...      ...            ...            ...      ...   ...
# 755            1      128             88             39      110  36.5
# 758            1      106             76              0        0  37.5
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 1                       0.351   31        0
# ...

# %% [markdown]
# # Completed 🎉
